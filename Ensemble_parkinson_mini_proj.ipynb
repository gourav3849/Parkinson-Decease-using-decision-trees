# %% [markdown]
# Dear Participant,
#
# Parkinson’s Disease (PD) is a degenerative neurological disorder marked by decreased dopamine levels in the brain. It manifests itself through a deterioration of movement, including the presence of tremors and stiffness. There is commonly a marked effect on speech, including dysarthria (difficulty articulating sounds), hypophonia (lowered volume), and monotone (reduced pitch range). Additionally, cognitive impairments and changes in mood can occur, and risk of dementia is increased.
#
# Traditional diagnosis of Parkinson’s Disease involves a clinician taking a neurological history of the patient and observing motor skills in various situations. Since there is no definitive laboratory test to diagnose PD, diagnosis is often difficult, particularly in the early stages when motor effects are not yet severe. Monitoring progression of the disease over time requires repeated clinic visits by the patient. An effective screening process, particularly one that doesn’t require a clinic visit, would be beneficial. Since PD patients exhibit characteristic vocal features, voice recordings are a useful and non-invasive tool for diagnosis. If machine learning algorithms could be applied to a voice recording dataset to accurately diagnosis PD, this would be an effective screening step prior to an appointment with a clinician.
#
# Use the provided dataset in order to do your analysis.

# %% [markdown]
# #Attribute Information:
#
# #Matrix column entries (attributes):
# #name - ASCII subject name and recording number
# #MDVP:Fo(Hz) - Average vocal fundamental frequency
# #MDVP:Fhi(Hz) - Maximum vocal fundamental frequency
# #MDVP:Flo(Hz) - Minimum vocal fundamental frequency
# #MDVP:Jitter(%),MDVP:Jitter(Abs),MDVP:RAP,MDVP:PPQ,Jitter:DDP - Several
# #measures of variation in fundamental frequency
# #MDVP:Shimmer,MDVP:Shimmer(dB),Shimmer:APQ3,Shimmer:APQ5,MDVP:APQ,Shimmer:DDA - Several measures of variation in amplitude
# #NHR,HNR - Two measures of ratio of noise to tonal components in the voice
# #status - Health status of the subject (one) - Parkinson's, (zero) - healthy
# #RPDE,D2 - Two nonlinear dynamical complexity measures
# #DFA - Signal fractal scaling exponent
# #spread1,spread2,PPE - Three nonlinear measures of fundamental frequency variation

# %%
# Import required library
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib.colors import ListedColormap

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### Q1. Load the dataset

# %%
df=pd.read_csv('parkinsons.csv')
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %% [markdown]
# ### Q2. Use the .describe() method on the dataset and state any insights you may come across.

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
df['MDVP:Jitter(Abs)'].nunique()
# Out:
# 19

# %%
df=df.drop('name',axis=1)
df.shape
# Out:
# (195, 23)

# %%
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %% [markdown]
# Most of the features have a very low variance.

# %% [markdown]
# ### Q3. Check for class imbalance. Do people with Parkinson's have greater representation in the dataset?

# %%
sns.countplot(df['status'])
plt.text(x=-0.05,y=df['status'].value_counts()[0]+1,s=round(df['status'].value_counts(normalize=True)[0]*100,2))
plt.text(x=0.95,y=df['status'].value_counts()[1]+1,s=round(df['status'].value_counts(normalize=True)[1]*100,2))
plt.show()

# %% [markdown]
# ### Q4. Check for missing vaues and take necessary measures by dropping observation or imputing them.

# %% [markdown]
# There are no missing values

# %% [markdown]
# ### Q5. Plot the distribution of all the features. State any observations you can make based on the distribution plots.

# %%
fig,ax=plt.subplots(11,2,figsize=(15,20))

for figu,a in zip(df.drop('status',axis=1),ax.flatten()):
    figur=sns.histplot(df[figu],ax=a)
    figur.set_xlabel(f"{figu}")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Q6. Check for outliers in the data. Are there any variables with high amount of outliers.

# %%
fig,ax=plt.subplots(11,2,figsize=(15,20))

for figu,a in zip(df.drop('status',axis=1),ax.flatten()):
    figur=sns.boxplot(df[figu],ax=a)
    figur.set_xlabel(f"{figu}")

plt.tight_layout()
plt.show()

# %% [markdown]
# There are outliers present in the data

# %% [markdown]
# ### Q7. Are there any strong correlations among the independent features?

# %%
X=df.drop('status',axis=1)
y=df['status']

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif

VIF=[round(vif(X.values,i),2) for i in range(X.shape[1])]

df_vif=pd.DataFrame(VIF,index=X.columns,columns=['VIF'])
df_vif
# Out:
#                           VIF
# MDVP:Fo(Hz)            102.24
# MDVP:Fhi(Hz)             8.88
# MDVP:Flo(Hz)            18.05
# MDVP:Jitter(%)         506.56
# MDVP:Jitter(Abs)       122.72
# MDVP:RAP           3101964.45
# MDVP:PPQ               273.80
# Jitter:DDP         3103948.97
# MDVP:Shimmer          2653.66
# MDVP:Shimmer(dB)       303.10
# Shimmer:APQ3      51152986.52
# Shimmer:APQ5           342.84
# MDVP:APQ               184.05
# Shimmer:DDA       51126303.41
# NHR                     16.00
# HNR                    132.11
# RPDE                    55.61
# DFA                    414.91
# spread1                384.37
# spread2                 23.08
# D2                     112.65
# PPE                    133.49

# %% [markdown]
# Yes there are strong multicolinearity among independent varaibles

# %% [markdown]
# ### Q8. Split dataset into training & test dataset

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ### Q9. Create a default decision tree model using criterion = Entropy

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.tree import export_graphviz
import IPython
from IPython.display import Image
import pydotplus

# %%
dt=DecisionTreeClassifier(criterion='entropy',random_state=1)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=1)

# %%
labels=X.columns
dot_plot=tree.export_graphviz(dt,feature_names=labels,class_names=['0','1'])
graph=pydotplus.graph_from_dot_data(dot_plot)
Image(graph.create_png())

# %%
from sklearn.metrics import classification_report
decision_pred=dt.predict(X_train)
print("Train data report")
print(classification_report(y_train,decision_pred))
# Out:
# Train data report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        31
#            1       1.00      1.00      1.00        99
#
#     accuracy                           1.00       130
#    macro avg       1.00      1.00      1.00       130
# weighted avg       1.00      1.00      1.00       130

# %%
decision_pred=dt.predict(X_test)
print("Test data report")
print(classification_report(y_test,decision_pred))
# Out:
# Test data report
#               precision    recall  f1-score   support
#
#            0       0.93      0.76      0.84        17
#            1       0.92      0.98      0.95        48
#
#     accuracy                           0.92        65
#    macro avg       0.93      0.87      0.89        65
# weighted avg       0.92      0.92      0.92        65

# %% [markdown]
# ### Q10.  Use regularization parameters of max_depth, min_sample_leaf to recreate the model. What is the impact on the model accuracy? How does regularization help?

# %%
dt=DecisionTreeClassifier(criterion='entropy',random_state=1,max_depth=3,min_samples_leaf=5)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=5,
#                        random_state=1)

# %%
decision_pred=dt.predict(X_train)
print("Train data report")
print(classification_report(y_train,decision_pred))
# Out:
# Train data report
#               precision    recall  f1-score   support
#
#            0       0.78      0.94      0.85        31
#            1       0.98      0.92      0.95        99
#
#     accuracy                           0.92       130
#    macro avg       0.88      0.93      0.90       130
# weighted avg       0.93      0.92      0.93       130

# %%
from sklearn.metrics import classification_report
decision_pred=dt.predict(X_test)
print("Test data report")
print(classification_report(y_test,decision_pred))
# Out:
# Test data report
#               precision    recall  f1-score   support
#
#            0       0.72      0.76      0.74        17
#            1       0.91      0.90      0.91        48
#
#     accuracy                           0.86        65
#    macro avg       0.82      0.83      0.82        65
# weighted avg       0.86      0.86      0.86        65

# %% [markdown]
# The accuracy of our 2nd model has reduced but its actually good as out train and test results are more close while earlier our model was overfit on train data but didnt perform same on test data

# %% [markdown]
# ### Q11. Implement a Random Forest model. What is the optimal number of trees that gives the best result?

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
tuned_params=[{'n_estimators':[10,30,50,100,150,200,250,300]}]

# %%
rf=RandomForestClassifier()
gsv=GridSearchCV(estimator=rf,param_grid=tuned_params,cv=3,scoring='roc_auc')
gsv.fit(X,y)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(),
#              param_grid=[{'n_estimators': [10, 30, 50, 100, 150, 200, 250,
#                                            300]}],
#              scoring='roc_auc')

# %%
gsv.best_params_
# Out:
# {'n_estimators': 100}
